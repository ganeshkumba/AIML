# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
path = "/content/test.csv"
pd.read_csv(path)
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0      0.1        193  ...  16        226      1412  3476    12     7
# 1      0.8        191  ...  12        746       857  3895     6     0
# 2      0.9        186  ...   4       1270      1366  2396    17    10
# 3      0.5         96  ...  20        295      1752  3893    10     0
# 4      0.5        108  ...  18        749       810  1773    15     8
# ..     ...        ...  ...  ..        ...       ...   ...   ...   ...
# 995    0.5        170  ...  17        644       913  2121    14     8
# 996    0.9        186  ...   2       1152      1632  1933     8     1
# 997    0.5         80  ...  12        477       825  1223     5     0
# 998    0.4        171  ...  12         38       832  2509    15    11
# 999    0.1        140  ...  19        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# 0            2        0             1     0
# 1            7        1             0     0
# 2           10        0             1     1
# 3            7        1             1     0
# 4            7        1             0     1
# ..         ...      ...           ...   ...
# 995         15        1             1     0
# 996         19        0             1     1
# 997         14        1             0     0
# 998          6        0             1     0
# 999          3        1             0     1
#
# [1000 rows x 21 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.linear_model import LinearRegression
from sklearn import metrics


data = pd.read_csv('/content/test.csv')

X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=40)

# %% [markdown]
# 1.SUPPORT VECTOR MACHINE

# %%
svm_model = SVC()
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.55      0.55        47
#            1       0.60      0.58      0.59        53
#
#     accuracy                           0.57       100
#    macro avg       0.57      0.57      0.57       100
# weighted avg       0.57      0.57      0.57       100

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train, y_train)

y_pred_dt = dt_model.predict(X_test)

print('\nDecision Tree Metrics:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_dt))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_dt))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dt)))

plt.figure(figsize=(10, 8))
from sklearn import tree
# Use df.columns[:-1] to get feature names from the original DataFrame, excluding the target variable column
tree.plot_tree(dt_model, feature_names=df.columns[:-1], filled=True)
plt.title("Decision Tree Visualization")
plt.show()
# Out:
# Decision Tree Metrics:
# Mean Absolute Error: 0.5172413793103449
# Mean Squared Error: 0.5172413793103449
# Root Mean Squared Error: 0.7191949522280763

# %% [markdown]
# 2.Linear Regression Implementation

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
y_pred_lr = lr_model.predict(X_test)

print('Linear Regression Metrics:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_lr))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_lr))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_lr)))
# Out:
# Linear Regression Metrics:
# Mean Absolute Error: 0.4965141866185744
# Mean Squared Error: 0.2538870175761925
# Root Mean Squared Error: 0.5038720249986026

# %% [markdown]
# 3.Decision Tree Implementation

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train, y_train)

y_pred_dt = dt_model.predict(X_test)

print('\nDecision Tree Metrics:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_dt))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_dt))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dt)))

plt.figure(figsize=(10, 8))
from sklearn import tree
tree.plot_tree(dt_model, feature_names=X.columns, filled=True)
plt.title("Decision Tree Visualization")
plt.show()
# Out:
# Decision Tree Metrics:
# Mean Absolute Error: 0.5172413793103449
# Mean Squared Error: 0.5172413793103449
# Root Mean Squared Error: 0.7191949522280763
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-81c49b2f12fe> in <cell line: 15>()
#      13 plt.figure(figsize=(10, 8))
#      14 from sklearn import tree
# ---> 15 tree.plot_tree(dt_model, feature_names=X.columns, filled=True)
#      16 plt.title("Decision Tree Visualization")
#      17 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train, y_train)

y_pred_dt = dt_model.predict(X_test)

print('\nDecision Tree Metrics:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_dt))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_dt))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dt)))

plt.figure(figsize=(10, 8))
from sklearn import tree
# Assuming 'df' is your original Pandas DataFrame containing features and target variable:
# If you don't have 'df' anymore, you can either reload it or manually provide a list of feature names.
# For example, if you know the feature names are ['feature1', 'feature2', ...], you can use:
# feature_names=['feature1', 'feature2', ...]
tree.plot_tree(dt_model, feature_names=df.columns[:-1], filled=True)  # Use df.columns[:-1] to get feature names, excluding the target variable
plt.title("Decision Tree Visualization")
plt.show()
# Out:
# Decision Tree Metrics:
# Mean Absolute Error: 0.5172413793103449
# Mean Squared Error: 0.5172413793103449
# Root Mean Squared Error: 0.7191949522280763

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train, y_train)

y_pred_dt = dt_model.predict(X_test)

print('\nDecision Tree Metrics:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_dt))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_dt))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dt)))

plt.figure(figsize=(10, 8))
from sklearn import tree
# Get feature names from the original DataFrame 'df'
feature_names = df.columns[:-1]  # Exclude the target variable column

tree.plot_tree(dt_model, feature_names=feature_names, filled=True)  # Use feature_names here
plt.title("Decision Tree Visualization")
plt.show()
# Out:
# Decision Tree Metrics:
# Mean Absolute Error: 0.5172413793103449
# Mean Squared Error: 0.5172413793103449
# Root Mean Squared Error: 0.7191949522280763

# %% [markdown]
# 4.Random Forest Implementation

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

print('\nRandom Forest Metrics:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_rf))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_rf))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_rf)))
# Out:
# Random Forest Metrics:
# Mean Absolute Error: 0.49256157635467984
# Mean Squared Error: 0.2541689655172414
# Root Mean Squared Error: 0.5041517286663226

# %%
feature_importances = rf_model.feature_importances_
print("\nFeature Importances:")

# Assuming 'df' is your original DataFrame and 'X' was derived from it
# If you don't have 'df' anymore, replace df.columns[:-1] with a list of your feature names
for i, feature in enumerate(df.columns[:-1]):  # Use df.columns[:-1] to get feature names, excluding the target variable
    print(f"{feature}: {feature_importances[i]}")
# Out:
# Feature Importances:
# id: 0.0881285392672774
# battery_power: 0.08676027678752321
# blue: 0.008928177466848663
# clock_speed: 0.04827375036607634
# dual_sim: 0.008836044476899998
# fc: 0.04932731617627631
# four_g: 0.006824485669274969
# int_memory: 0.06631467012376556
# m_dep: 0.04061325391173166
# mobile_wt: 0.09692855692522798
# n_cores: 0.03269698755507001
# pc: 0.053204061407925746
# px_height: 0.0853914846231927
# px_width: 0.08795105887913886
# ram: 0.0745370976263145
# sc_h: 0.04866541194598437
# sc_w: 0.04208093284501532
# talk_time: 0.055966761594356776
# three_g: 0.009603330196097166
# touch_screen: 0.008967802156002444

# %%
feature_importances = rf_model.feature_importances_
print("\nFeature Importances:")

feature_importances = rf_model.feature_importances_
print("\nFeature Importances:")

# Assuming 'df' is the original Pandas DataFrame used to create X:
for i, feature in enumerate(df.columns[:-1]):  # Use df.columns to get feature names
    print(f"{feature}: {feature_importances[i]}")
# Out:
# Feature Importances:
#
# Feature Importances:
# id: 0.0881285392672774
# battery_power: 0.08676027678752321
# blue: 0.008928177466848663
# clock_speed: 0.04827375036607634
# dual_sim: 0.008836044476899998
# fc: 0.04932731617627631
# four_g: 0.006824485669274969
# int_memory: 0.06631467012376556
# m_dep: 0.04061325391173166
# mobile_wt: 0.09692855692522798
# n_cores: 0.03269698755507001
# pc: 0.053204061407925746
# px_height: 0.0853914846231927
# px_width: 0.08795105887913886
# ram: 0.0745370976263145
# sc_h: 0.04866541194598437
# sc_w: 0.04208093284501532
# talk_time: 0.055966761594356776
# three_g: 0.009603330196097166
# touch_screen: 0.008967802156002444

# %% [markdown]
# 5.KNN

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
url = "/content/test.csv"
df = pd.read_csv(url)

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
param_grid = {'n_neighbors': np.arange(1, 31)}
knn = KNeighborsClassifier()
grid_search = GridSearchCV(knn, param_grid, cv=5)
grid_search.fit(X_train, y_train)
best_knn = grid_search.best_estimator_
print(f"Best n_neighbors: {grid_search.best_params_['n_neighbors']}")
y_pred = best_knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy*175:.2f}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Best n_neighbors: 17
# Accuracy: 87.50
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      0.48      0.47        93
#            1       0.53      0.51      0.52       107
#
#     accuracy                           0.50       200
#    macro avg       0.50      0.50      0.50       200
# weighted avg       0.50      0.50      0.50       200

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(y), yticklabels=np.unique(y))
plt.title("Confusion Matrix for KNN Classifier")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# 6.precision, recall and F1 score

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# Load data
url = "/content/test.csv"
df = pd.read_csv(url)

# Assuming the last column is the target variable
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Target variable

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Hyperparameter tuning using GridSearchCV
param_grid = {'n_neighbors': np.arange(1, 31)}  # Test n_neighbors from 1 to 30
knn = KNeighborsClassifier()
grid_search = GridSearchCV(knn, param_grid, cv=5)  # 5-fold cross-validation
grid_search.fit(X_train, y_train)

# Best parameters and model
best_knn = grid_search.best_estimator_
print(f"Best n_neighbors: {grid_search.best_params_['n_neighbors']}")

# Predictions
y_pred = best_knn.predict(X_test)


print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Best n_neighbors: 17
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      0.48      0.47        93
#            1       0.53      0.51      0.52       107
#
#     accuracy                           0.50       200
#    macro avg       0.50      0.50      0.50       200
# weighted avg       0.50      0.50      0.50       200
